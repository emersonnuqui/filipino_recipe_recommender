# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os
import time
from datetime import datetime

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
import re
import unicodedata
import string

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %% [markdown]
# ## Import data

# %%
kawaling_pinoy_df = pd.read_csv("data/kawaling_pinoy.csv")
panlasang_pinoy_df = pd.read_csv("data/panlasang_pinoy.csv")

# %%
display(kawaling_pinoy_df, panlasang_pinoy_df)
# Out:
#                                                    url  \
# 0     https://www.kawalingpinoy.com/salted-egg-shrimp/
# 1    https://www.kawalingpinoy.com/chop-suey-with-t...
# 2    https://www.kawalingpinoy.com/ginataang-kalaba...
# 3    https://www.kawalingpinoy.com/pineapple-upside...
# 4                  https://www.kawalingpinoy.com/biko/
# ..                                                 ...
# 591  https://www.kawalingpinoy.com/garlic-butter-fr...
# 592  https://www.kawalingpinoy.com/tinolang-manok-c...
# 593  https://www.kawalingpinoy.com/tilapia-with-bla...
# 594          https://www.kawalingpinoy.com/pork-adobo/
# 595   https://www.kawalingpinoy.com/sinigang-na-baboy/
#
#                                           food                  course  \
# 0                           Salted Eggs Shrimp             Main Entree
# 1    Chop Suey with Tofu and Shitake Mushrooms             Main Entree
# 2           Ginataang Kalabasa, Sitaw at Hipon  Main Entree, Side Dish
# ...

# %%
display(kawaling_pinoy_df.isna().sum(), panlasang_pinoy_df.isna().sum())
# Out:
# url             0
# food            0
# course          0
# ingredients     1
# instructions    0
# dtype: int64
# url              0
# food             0
# course           0
# ingredients     72
# instructions     0
# dtype: int64

# %%
recipe_df = pd.concat([kawaling_pinoy_df, panlasang_pinoy_df], axis=0)
recipe_df = recipe_df.dropna(subset=["ingredients"]).reset_index(drop=True)
recipe_df.rename(columns={"ingredients": "ingredients_raw", "instructions":"instructions_raw"}, inplace=True)

# %%
recipe_df['ingredients_raw'].str.lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 recipe_df['ingredients_raw'].str.lower().strip()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'strip'

# %%
def text_preprocessing(df):
    df = df['ingredients'].str.lower()
